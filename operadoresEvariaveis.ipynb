# %% [markdown]
# # Como utilizar operadores aritméticos, relacionais e lógicos

# %% [markdown]
# # Comentarios
#
# Comentário de uma linha ( )
# *   '#' Usar para comentar uma linha do código
# *   Comentário de múltiplas linhas “”” Usar para o cabeçalho do código Usar 3 aspas “””

# %% [markdown]
# # Operadores Aritméticos

# %%
#Adição
10 + 2
# Out:
# 12

# %%
#Subtração
10 - 2
# Out:
# 8

# %%
#Multiplicação
10 * 2
# Out:
# 20

# %%
#Divisão
10 / 2
# Out:
# 5.0

# %%
#Divisão inteira
10 // 2
# Out:
# 5

# %%
#Resto da divisão
10 % 2
# Out:
# 0

# %%
#Potenciação
10 ** 2
# Out:
# 100

# %% [markdown]
# # Operadores Relacionais

# %%
# Menor
10 < 2
# Out:
# False

# %%
# Menor igual
10 <= 2
# Out:
# False

# %%
# Maior
10 > 2
# Out:
# True

# %%
# Maior igual
10 >= 2
# Out:
# True

# %%
# Igual
10 == 2
# Out:
# False

# %%
# Diferente
10 != 2
# Out:
# True

# %% [markdown]
# # Operadores Lógicos

# %% [markdown]
# *   And
# *   Or
# *   Not

# %% [markdown]
# Tabela Verdade

# %% [markdown]
# And

# %%
print(10 > 2 and 4 < 6 )   # V and V - V
print(10 > 2 and 4 > 6 )   # V and F - F
print(10 < 2 and 4 < 6 )   # V and F - F
print(10 < 2 and 4 > 6 )   # F and F - F

# %% [markdown]
# Or

# %%
print(10 > 2 or 4 < 6 )    # V or V - V
print(10 > 2 or 4 > 6 )    # V or F - V
print(10 < 2 or 4 < 6 )    # F or V - V
print(10 < 2 or 4 > 6 )    # F or F - F

# %% [markdown]
# Not

# %%
not 10 > 2    # V - F

# %%
not 10 <      # F - V

# %% [markdown]
# # Variaveis

# %% [markdown]
# Variaveis estão alocadas em espaços da memoria

# %%
x = 10
print(x)
# Out:
# 10
