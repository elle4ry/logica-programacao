# %% [markdown]
# # De olho no código

# %%
# Pedir ao usuário para inserir a primeira nota;
# Armazenar a primeira nota em uma variável;

nota1 = input("Digite a primeira nota: ")
# Out:
# Digite a primeira nota: 231

# %%
# Pedir ao usuário para inserir a segunda nota;
# Armazenar a segunda nota em outra variável

nota2 = input("Digite a segunda nota: ")
# Out:
# Digite a segunda nota: 312

# %%
notaUM_convert= int(nota1)
type(notaUM_convert)
# Out:
# int

# %%
notaDOIS_convert= int(nota2)
type(notaDOIS_convert)
# Out:
# int

# %%
# Calcular a média das duas notas;
media = (notaUM_convert + notaDOIS_convert) / 2

# Exibir o resultado da média na tela
print(media)
# Out:
# 271.5

# %% [markdown]
# # Verificação de senha

# %%
#Definir senha
senha_sistema = '123456'

# %%
#Solicitar senha
senha_usuario = input('Digite sua senha: ')
# Out:
# Digite sua senha: 654

# %%
if senha_sistema == senha_usuario:
    print('Acesso permitido')
else:
    print('Acesso negado')
# Out:
# Acesso negado

# %% [markdown]
# # Organizar feedbacks

# %%
#Lista de feedbacks
feedbacks = ['ótimo serviço', 'equipe de sucesso', 'otima explicação']

# %%
#Dicionario com informação de um cliente
cliente = {
    'nome': 'João',
    'idade': 25,
    'feedbacks': 'atendimento rapido'
}

# %%
#Imprimir feedback da lista
print('feedback dos clientes')
for feedback in feedbacks:
    print(feedback)
# Out:
# feedback dos clientes
# ótimo serviço
# equipe de sucesso
# otima explicação

# %%
#Imprimir as informações do cliente
print("\nInformações do cliente:")
print("Nome:", cliente["nome"])
print("Idade:", cliente["idade"])
print("Feedback:", cliente["feedbacks"])
# Out:
# Informações do cliente:
# Nome: João
# Idade: 25
# Feedback: atendimento rapido

# %% [markdown]
# # Estrutura de repetição

# %%
#Loop while
contador = 0
while contador < 5:
    print('adicionando',contador)
    contador += 1
# Out:
# adicionando 0
# adicionando 1
# adicionando 2
# adicionando 3
# adicionando 4

# %%
#Loop for
frutas = ['maça', 'banana', 'laranja']
for fruta in frutas:
    print('eu gosto de',fruta)
# Out:
# eu gosto de maça
# eu gosto de banana
# eu gosto de laranja

# %% [markdown]
# # Notas de alunos

# %%
#Lista de notas dos alunos
notas = [85, 65, 23, 98, 68]

# %%
#Calcula a média de notas
soma = 0
for nota in notas:
  soma += nota
  media = soma / len(notas)

# %%
#Classifica os alunos com base na média
alunos_aprovados = []
alunos_reprovados = []
for nota in notas:
  if nota >= media:
    alunos_aprovados.append(nota)
  else:
    alunos_reprovados.append(nota)

# %%
#Imprime os resultados
print('Notas dos alunos:', notas)
print('Média de notas:', media)
print('Alunos aprovados:', alunos_aprovados)
print('Alunos reprovados:', alunos_reprovados)
# Out:
# Notas dos alunos: [85, 65, 23, 98, 68]
# Média de notas: 67.8
# Alunos aprovados: [85, 98, 68]
# Alunos reprovados: [65, 23]
